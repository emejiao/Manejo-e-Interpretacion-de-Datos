# %%
import pandas as pd
lista=pd.read_excel('C://Users/Enrique Mejia/Documents/LISTAS_DE_CLASE.xls', skiprows=[0, 1, 2, 3], header=1)
lista[['ESTUDIANTE', 'CODIGO ESTUDIANTE']]
# Out:
#                            ESTUDIANTE  CODIGO ESTUDIANTE
# 0        ALFONSO NUÑEZ BETHSY NATALIA          2181523.0
# 1                                 NaN                NaN
# 2         ALFONSO ORTIZ HEIDY LILIANA          2162174.0
# 3                                 NaN                NaN
# 4     BARRIOS GALVIS KERSTY KRUPSKAVA          2182843.0
# ..                                ...                ...
# 60       TARAZONA MORENO JULIAN DAVID          2191658.0
# 61                                NaN                NaN
# 62  VALDIVIESO RODRIGUEZ MARIA CAMILA          2190111.0
# 63                                NaN                NaN
# 64             VEGA LEON MIGUEL ANGEL          2180091.0
#
# [65 rows x 2 columns]

# %%
lista1=lista[['ESTUDIANTE', 'CODIGO ESTUDIANTE']].dropna(axis=0, inplace=False).to_excel('C://Users/Enrique Mejia/Documents/Lista_IQC_2021-1.xlsx')

# %%
#lista1.to_excel('C://Users/Enrique Mejia/Documents/LISTAS_DE_CLASE_IQC_2021-1.xlsx')

# %%
import pdfkit as pdf
lista1=pd.read_excel('C://Users/Enrique Mejia/Documents/Lista_IQC_2021-1.xlsx', usecols=[2, 3], header=0)
N1=pd.read_excel('C://Users/Enrique Mejia/Documents/2021-1-24712-B1-Presencial-Examen Tema I-calificaciones.xlsx', usecols=[10], header=0)
N2=pd.read_excel('C://Users/Enrique Mejia/Documents/2021-1-24712-B1-Presencial-Examen Tema 2 Modelos Simples-calificaciones.xlsx', usecols=[10], header=0)
list_n2.to_html('C://Users/Enrique Mejia/Documents/N2_IQC_2021-1.html')

Notas = pd.concat([lista1, N1], axis =1)
Notas = pd.concat([Notas, N2], axis =1)
# Out:
#     CODIGO ESTUDIANTE Calificación/5,00
# 0             2181523              3,00
# 1             2162174              2,33
# 2             2182843              2,50
# 3             2190105              4,50
# 4             2183267              3,00
# 5             2180512              4,50
# 6             2190113              4,33
# 7             2072262              2,17
# 8             2191657              4,17
# 9             2190120              4,17
# 10            2181946              2,33
# 11            2190108              4,00
# 12            2151626              2,50
# 13            2180878              3,33
# 14            2182710              3,83
# 15            2181530              2,83
# 16            2183081              2,83
# 17            2190115              3,50
# 18            2160758              3,33
# 19            2180083              3,17
# 20            2181838              4,17
# 21            2172044              3,33
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(9,6))
plt.rcParams["font.family"] = 'Times New Roman'
cell_text = []
for row in range(len(list_n2)):
    cell_text.append(list_n2.iloc[row])

ax.table(cellText=cell_text, colLabels=list_n2.columns, cellLoc='center', edges='open', colWidths=[0.2, 0.1], loc='center')
ax.axis('off')

fig.savefig('table.pdf')
plt.show()

# %%
plt.rcParams?
# Out:
# Object `plt.Params` not found.
